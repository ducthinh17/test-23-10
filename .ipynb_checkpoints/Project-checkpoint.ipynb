# %%
#ngôn ngữ python
import pandas as pd    # vẽ bảng - xủ lý data trong bảng 
import numpy as np    # tính toán
import matplotlib.pyplot as plt        #biểu đồ cơ bản
import seaborn as sns                   # biểu đò phức tạp hơn

# %%
# load dataset
data = pd.read_csv('/Users/thinhpld0/Desktop/document/movie121-1.csv')

# %%
data.head()
# Out:
#                       Title US Gross Worldwide Gross  US DVD Sales  \
# 0       The Broadway Melody  2800000         4358000           NaN
# 1             Hell's Angels  Unknown         Unknown           NaN
# 2                 Mata Hari   900000          900000           NaN
# 3     It Happened One Night  2500000         2500000           NaN
# 4  Alexander's Ragtime Band  4000000         4000000           NaN
#
#    Production Budget Release Date MPAA Rating  Running Time (min)  \
# 0           379000.0     April-05         NaN                 NaN
# 1          4000000.0     April-05         NaN                 NaN
# 2           558000.0     April-05         NaN                 NaN
# 3           325000.0     April-05         NaN                 NaN
# 4          2000000.0     April-05         NaN                 NaN
#
#         Distributor               Source      Major Genre Creative Type  \
# 0               MGM  Original Screenplay          Musical           NaN
# ...

# %%
# %matplotlib inline

# %%
clean = ['Running Time (min)','MPAA Rating','Director','Title']
af_clean = data.drop(clean,axis=1)
af_clean.head (20)
# Out:
#     US Gross Worldwide Gross  US DVD Sales  Production Budget Release Date  \
# 0    2800000         4358000           NaN           379000.0     April-05
# 1    Unknown         Unknown           NaN          4000000.0     April-05
# 2     900000          900000           NaN           558000.0     April-05
# 3    2500000         2500000           NaN           325000.0     April-05
# 4    4000000         4000000           NaN          2000000.0     April-05
# 5    4000000         4000000           NaN          1644000.0     April-05
# 6    9000000         9000000           NaN          1500000.0     April-05
# 7    9172000         9172000           NaN          2000000.0     April-05
# 8    6000000         6000000           NaN          1288000.0     April-05
# 9   10462500        10462500           NaN           950000.0     April-05
# 10   3500000         3500000           NaN          2361000.0     April-05
# ...

# %%
final= af_clean.fillna(af_clean.median())
final= a.fillna(method='ffill')
final= b.fillna(method='bfill')
final.head(20)

# %%
g = sns.PairGrid(final) 
g.map_diag(sns.histplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot);

# %%
data.groupby('Major Genre').describe()
# Out:
#                     US DVD Sales                                          \
#                            count          mean           std         min
# Major Genre
# Action                      74.0  4.857633e+07  5.962422e+07    970318.0
# Adventure                   74.0  6.646177e+07  7.516776e+07   1757108.0
# Black Comedy                 4.0  1.122259e+07  8.334064e+06    910568.0
# Comedy                     117.0  3.710346e+07  4.110123e+07   1374953.0
# Concert/Performance          1.0  1.815474e+07           NaN  18154740.0
# Documentary                  5.0  2.242629e+07  2.497751e+07   2987505.0
# Drama                      138.0  2.285963e+07  2.853710e+07    618454.0
# Horror                      47.0  2.111216e+07  2.048634e+07    943385.0
# Musical                      9.0  3.433146e+07  3.316750e+07   3120029.0
# Romantic Comedy             26.0  3.214407e+07  2.849918e+07   7571152.0
# Thriller/Suspense           62.0  1.984263e+07  1.695923e+07    893953.0
# ...

# %%
# irrelevant fields
fields = ['MPAA Rating','Director', 'Title','Running Time (min)','US DVD Sales','Release Date','Creative Type','Source'
         ,'US Gross','Distributor','IMDB Votes','Rotten Tomatoes Rating']
df_new = data.drop(fields, axis = 1)

# %%
df_new
# Out:
#      Worldwide Gross  Production Budget      Major Genre  IMDB Rating
# 0            4358000           379000.0          Musical          6.7
# 1            Unknown          4000000.0              NaN          7.9
# 2             900000           558000.0              NaN          2.2
# 3            2500000           325000.0  Romantic Comedy          8.3
# 4            4000000          2000000.0            Drama          NaN
# ...              ...                ...              ...          ...
# 3196               0          5000000.0              NaN          NaN
# 3197               0         20000000.0              NaN          NaN
# 3198               0         30000000.0              NaN          NaN
# 3199               0         50000000.0              NaN          NaN
# 3200          627422         18000000.0              NaN          5.2
#
# [3201 rows x 4 columns]

# %%
df_new.groupby('Major Genre').describe()
# Out:
#                     Production Budget                                         \
#                                 count          mean           std        min
# Major Genre
# Action                          420.0  5.468615e+07  4.510069e+07     7000.0
# Adventure                       274.0  6.884270e+07  5.484539e+07   200000.0
# Black Comedy                     36.0  1.281528e+07  1.074977e+07   500000.0
# Comedy                          674.0  2.842205e+07  2.902353e+07    27000.0
# Concert/Performance               5.0  6.100000e+06  5.200961e+06  3000000.0
# Documentary                      43.0  4.215612e+06  1.235085e+07      218.0
# Drama                           789.0  2.258202e+07  2.354286e+07     7000.0
# Horror                          219.0  1.852589e+07  2.161121e+07    15000.0
# Musical                          53.0  2.137769e+07  2.230246e+07   379000.0
# Romantic Comedy                 137.0  2.835201e+07  2.259135e+07   200000.0
# ...

# %%
sns.set_theme()

# %%
sns.pairplot(data= df_new,hue='Major Genre');

# %%
# chi phí sản xuất của từng loại film
#sns.displot(data=df_new,x ='Worldwide Gross', col='Major Genre', kde=True);     
                            #specify

# %%
#chi phí sản xuất / rating

#sns.jointplot(x='Production Budget' , y='IMDB Rating', data=df_new, kind= 'hex',color='r');

# %%
my_list = [1,2,3]
my_list

# %%
#sns.jointplot(data=df_new, x='IMDB Rating', y='Worldwide Gross');                  # so người với cánh
