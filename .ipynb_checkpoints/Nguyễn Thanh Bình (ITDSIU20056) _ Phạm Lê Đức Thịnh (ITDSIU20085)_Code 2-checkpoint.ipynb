# %%
# Setting up Packages
import json

from datetime import datetime, timedelta
import requests
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset
data = pd.read_csv('/Users/thinhpld0/Desktop/document/movie_1.csv')

# %%
# %matplotlib inline

# %%
sns.set_theme()

# %%
data.head()
# Out:
#                       Title US Gross Worldwide Gross  US DVD Sales  \
# 0       The Broadway Melody  2800000         4358000           NaN
# 1             Hell's Angels  Unknown         Unknown           NaN
# 2                 Mata Hari   900000          900000           NaN
# 3     It Happened One Night  2500000         2500000           NaN
# 4  Alexander's Ragtime Band  4000000         4000000           NaN
#
#    Production Budget Release_Date MPAA Rating  Running Time (min)  \
# 0           379000.0        5-Apr         NaN                 NaN
# 1          4000000.0        5-Apr         NaN                 NaN
# 2           558000.0        5-Apr         NaN                 NaN
# 3           325000.0        5-Apr         NaN                 NaN
# 4          2000000.0        5-Apr         NaN                 NaN
#
#         Distributor               Source      Major Genre Creative Type  \
# 0               MGM  Original Screenplay          Musical           NaN
# ...

# %%
g = sns.PairGrid(data) 
g.map_diag(sns.histplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot);

# %%
sns.pairplot(data= data,hue='Major Genre');
# Out:
# /Users/thinhpld0/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
clean = ['Running Time (min)','MPAA Rating','Director','Title']    #xoá cột
af_clean = data.drop(clean,axis=1)
af_clean.head (3200)
# Out:
#      US Gross Worldwide Gross  US DVD Sales  Production Budget Release_Date  \
# 0     2800000         4358000           NaN           379000.0        5-Apr
# 1     Unknown         Unknown           NaN          4000000.0        5-Apr
# 2      900000          900000           NaN           558000.0        5-Apr
# 3     2500000         2500000           NaN           325000.0        5-Apr
# 4     4000000         4000000           NaN          2000000.0        5-Apr
# ...       ...             ...           ...                ...          ...
# 3195        0               0           NaN         27000000.0          TBD
# 3196        0               0           NaN          5000000.0          TBD
# 3197        0               0           NaN         20000000.0          TBD
# 3198        0               0           NaN         30000000.0          TBD
# 3199        0               0           NaN         50000000.0          TBD
#
# ...

# %%
final= af_clean.fillna(af_clean.median())

final= final.fillna(method='bfill')
final= final.fillna(method='ffill')
final= final.replace("Unknown", 0)
final= final.replace("0", 0)

A= final['US Gross'].median()

A


final= final.replace(0,A)
final
# Out:
#         US Gross Worldwide Gross  US DVD Sales  Production Budget  \
# 0        2800000         4358000    20331557.5           379000.0
# 1     21930418.0      21930418.0    20331557.5          4000000.0
# 2         900000          900000    20331557.5           558000.0
# 3        2500000         2500000    20331557.5           325000.0
# 4        4000000         4000000    20331557.5          2000000.0
# ...          ...             ...           ...                ...
# 3196  21930418.0      21930418.0    20331557.5          5000000.0
# 3197  21930418.0      21930418.0    20331557.5         20000000.0
# 3198  21930418.0      21930418.0    20331557.5         30000000.0
# 3199  21930418.0      21930418.0    20331557.5         50000000.0
# 3200  21930418.0          627422    20331557.5         18000000.0
#
#      Release_Date       Distributor                     Source  \
# 0           5-Apr               MGM        Original Screenplay
# ...

# %%
GRB = final.groupby('Major Genre')

# %%
GRB.describe()
# Out:
#                     US DVD Sales                                          \
#                            count          mean           std         min
# Major Genre
# Action                     471.0  2.476917e+07  2.565227e+07    970318.0
# Adventure                  318.0  3.106314e+07  4.101679e+07   1757108.0
# Black Comedy                36.0  1.931945e+07  3.792422e+06    910568.0
# Comedy                     719.0  2.305194e+07  1.764619e+07   1374953.0
# Concert/Performance          5.0  1.989619e+07  9.735024e+05  18154740.0
# Documentary                 53.0  2.052917e+07  6.955039e+06   2987505.0
# Drama                      846.0  2.074394e+07  1.152852e+07    618454.0
# Horror                     237.0  2.048636e+07  9.049934e+06    943385.0
# Musical                     62.0  2.236380e+07  1.299973e+07   3120029.0
# Romantic Comedy            152.0  2.235212e+07  1.242526e+07   7571152.0
# Thriller/Suspense          253.0  2.021174e+07  8.346594e+06    893953.0
# ...

# %%
std=np.std(data)

# %%
v= (l-m)/std

# %%
v
# Out:
# US DVD Sales                -0.761068
# Production Budget           -0.873121
# Running Time (min)         153.293510
# Rotten Tomatoes Rating     112.098402
# IMDB Rating               2551.526735
# IMDB Votes                  -0.594427
# dtype: float64

# %%
std
# Out:
# US DVD Sales              4.585442e+07
# Production Budget         3.558035e+07
# Running Time (min)        2.016267e+01
# Rotten Tomatoes Rating    2.807054e+01
# IMDB Rating               1.252080e+00
# IMDB Votes                4.493006e+04
# dtype: float64

# %%
l
# Out:
# 3201
